# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the Face Image
faceImage = cv2.imread('MM.jpeg')
plt.imshow(faceImage[:,:,::-1]);plt.title("Face")
# Out:
# Text(0.5, 1.0, 'Face')

# %%
faceImage.shape
# Out:
# (918, 612, 3)

# %%
#resized_faceImage.shape
faceImage.shape
# Out:
# (918, 612, 3)

# %%
# Load the Sunglass image with Alpha channel
# (http://pluspng.com/sunglass-png-1104.html)
glassPNG = cv2.imread('Documents/DIPT/Sturdy-Octo-Disco-Adding-Sunglasses-for-a-Cool-New-Look-main/Image-Source-PlusPNG.com.png',-1)
plt.imshow(glassPNG[:,:,::-1]);plt.title("glassPNG")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 # Load the Sunglass image with Alpha channel
#       2 # (http://pluspng.com/sunglass-png-1104.html)
#       3 glassPNG = cv2.imread('Documents/DIPT/Sturdy-Octo-Disco-Adding-Sunglasses-for-a-Cool-New-Look-main/Image-Source-PlusPNG.com.png',-1)
# ----> 4 plt.imshow(glassPNG[:,:,::-1]);plt.title("glassPNG")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Resize the image to fit over the eye region
glassPNG = cv2.resize(glassPNG,(3)
print("image Dimension ={}".format(glassPNG.shape))
# Out:
#   Cell In[24], line 2
#     glassPNG = cv2.resize(glassPNG,(300,100)
#                          ^
# SyntaxError: '(' was never closed

# %%
# Separate the Color and alpha channels
glassBGR = glassPNG[:,:,0:3]
glassMask1 = glassPNG[:,:,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Separate the Color and alpha channels
# ----> 2 glassBGR = glassPNG[:,:,0:3]
#       3 glassMask1 = glassPNG[:,:,3]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Display the images for clarity
plt.figure(figsize=[15,15])
plt.subplot(121);plt.imshow(glassBGR[:,:,::-1]);plt.title('Sunglass Color channels');
plt.subplot(122);plt.imshow(glassMask1,cmap='gray');plt.title('Sunglass Alpha channel');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Display the images for clarity
#       2 plt.figure(figsize=[15,15])
# ----> 3 plt.subplot(121);plt.imshow(glassBGR[:,:,::-1]);plt.title('Sunglass Color channels');
#       4 plt.subplot(122);plt.imshow(glassMask1,cmap='gray');plt.title('Sunglass Alpha channel');
#
# NameError: name 'glassBGR' is not defined

# %%
# Make a copy
#faceWithGlassesNaive = resized_faceImage.copy()
faceWithGlassesNaive = faceImage.copy()

# Replace the eye region with the sunglass image
faceWithGlassesNaive[135:185,110:300]=glassBGR

plt.imshow(faceWithGlassesNaive[...,::-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       2 #faceWithGlassesNaive = resized_faceImage.copy()
#       3 faceWithGlassesNaive = faceImage.copy()
#       4
#       5 # Replace the eye region with the sunglass image
# ----> 6 faceWithGlassesNaive[135:185,110:300]=glassBGR
#       7
#       8 plt.imshow(faceWithGlassesNaive[...,::-1])
#
# NameError: name 'glassBGR' is not defined

# %%
# Make the dimensions of the mask same as the input image.
# Since Face Image is a 3-channel image, we create a 3 channel image for the mask
glassMask = cv2.merge((glassMask1,glassMask1,glassMask1))

# Make the values [0,1] since we are using arithmetic operations
glassMask = np.uint8(glassMask/255)

# Make a copy
faceWithGlassesArithmetic = faceImage.copy()

# Get the eye region from the face image
eyeROI= faceWithGlassesArithmetic[135:185,110:300]

# Use the mask to create the masked eye region
maskedEye = cv2.multiply(eyeROI,(1-  glassMask ))

# Use the mask to create the masked sunglass region
maskedGlass = cv2.multiply(glassBGR,glassMask)

# Combine the Sunglass in the Eye Region to get the augmented image
eyeRoiFinal = cv2.add(maskedEye, maskedGlass)

# Display the intermediate results
plt.figure(figsize=[20,20])
plt.subplot(131);plt.imshow(maskedEye[...,::-1]);plt.title("Masked Eye Region")
plt.subplot(132);plt.imshow(maskedGlass[...,::-1]);plt.title("Masked Sunglass Region")
plt.subplot(133);plt.imshow(eyeRoiFinal[...,::-1]);plt.title("Augmented Eye and Sunglass")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Make the dimensions of the mask same as the input image.
#       2 # Since Face Image is a 3-channel image, we create a 3 channel image for the mask
# ----> 3 glassMask = cv2.merge((glassMask1,glassMask1,glassMask1))
#       4
#       5 # Make the values [0,1] since we are using arithmetic operations
#       6 glassMask = np.uint8(glassMask/255)
#
# NameError: name 'glassMask1' is not defined

# %%
# Replace the eye ROI with the output from the previous section
faceWithGlassesArithmetic[135:185,110:300]=eyeRoiFinal

# Display the final result
plt.figure(figsize=[20,20]);
plt.subplot(121);plt.imshow(faceImage[:,:,::-1]); plt.title("Original Image");
plt.subplot(122);plt.imshow(faceWithGlassesArithmetic[:,:,::-1]);plt.title("With Sunglasses");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Replace the eye ROI with the output from the previous section
# ----> 2 faceWithGlassesArithmetic[135:185,110:300]=eyeRoiFinal
#       3
#       4 # Display the final result
#       5 plt.figure(figsize=[20,20]);
#
# NameError: name 'eyeRoiFinal' is not defined
